# %%
import matplotlib.pyplot as plt
x=[10,20,25,35,40]
y=[150,100,250,400,350]
plt.figure(figsize=[8,6])
plt.subplot(2,2,1)
plt.title("interest in Engineering")
plt.xlabel("age")
plt.ylabel("student")
plt.plot(x,y,color="red",marker="^")
x1=[1,2,3,4,5]
y1=[50,45,60,38,65]
plt.subplot(2,2,2)
plt.bar(x1,y1,color="pink")
Department=["CSE","MEN","EEN","CEN","ECE"]
student=[30,15,20,18,22]
c=["red","orange","blue","green","yellow"]
ex=[0,0.12,0,0,0]
plt.subplot(2,2,3)
plt.pie(student,labels=Department,colors=c,explode=ex,shadow=True,autopct="%.f",startangle=400)
x=[23,45,32,45,41,56,65,53,63,49,28,42]
plt.subplot(2,2,4)
plt.hist(x,bins=len(x),edgecolor="red",color="pink")
plt.suptitle("data of depertment")
plt.show()
